# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=2, minor=7, micro=12, releaselevel='final', serial=0)

# %%
import pandas as pd
import quandl  

# Render our plots inline
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
#df = quandl.get('WIKI/GOOGL')
#df = quandl.get('SSE/SVHG')

# %%
#df.to_csv("GOOGL.csv")

#read from csv
df = pd.read_csv("GOOGL.csv")

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  3367.000000  3367.000000  3367.000000  3367.000000  3.367000e+03
# mean    587.826978   593.178372   581.935099   587.607915  7.915107e+06
# std     218.493835   219.120359   217.601539   218.459868  8.283209e+06
# min      99.090000   101.740000    95.960000   100.010000  5.211410e+05
# 25%     459.105000   463.005000   453.690000   458.240000  2.515600e+06
# 50%     561.830000   567.150000   556.667900   561.640000  5.156800e+06
# 75%     722.665000   730.495000   715.295000   721.945000  1.043960e+07
# max    1226.800000  1228.880000  1218.600000  1220.170000  8.215110e+07
#
#        Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# count  3367.000000       3367.0  3367.000000  3367.000000  3367.000000
# mean      0.168688          1.0   397.273651   400.715524   393.453506
# std       9.788251          0.0   242.903254   244.190768   241.387659
# ...

# %%
df.head()
# Out:
#          Date    Open    High     Low    Close      Volume  Ex-Dividend  \
# 0  2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 1  2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2  2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 3  2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 4  2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0          1.0  50.159839  52.191109  48.128568   50.322842   44659000.0
# 1          1.0  50.661387  54.708881  50.405597   54.322689   22834300.0
# 2          1.0  55.551482  56.915693  54.693835   54.869377   18256100.0
# 3          1.0  55.792225  55.972783  51.945350   52.597363   15247300.0
# 4          1.0  52.542193  54.167209  52.100830   53.164113    9188600.0

# %%
#SOme feartues
df = df[['Adj. Open' , 'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume']]

# %%
df.head()
# Out:
#    Adj. Open  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0  50.159839  50.159839  52.191109  48.128568   50.322842   44659000.0
# 1  50.661387  50.661387  54.708881  50.405597   54.322689   22834300.0
# 2  55.551482  55.551482  56.915693  54.693835   54.869377   18256100.0
# 3  55.792225  55.792225  55.972783  51.945350   52.597363   15247300.0
# 4  52.542193  52.542193  54.167209  52.100830   53.164113    9188600.0

# %%
df['Adj. Close'].plot()

# %%
#define new feature
#df['HL_PCT'] = 
#(df['Adj. High'] - df['Adj. Close'])/df['Adj. Close'] * 100
#df['PCT_Change'] = 
#(df['Adj. Close'] - df['Adj. Open'])/df['Adj. Open'] * 100
df[1:10, 'Adj. Close']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-4e6e6aefe516> in <module>()
#       4 #df['PCT_Change'] =
#       5 #(df['Adj. Close'] - df['Adj. Open'])/df['Adj. Open'] * 100
# ----> 6 df[1:10, 'Adj. Close']
#
# /Users/jvsingh/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Users/jvsingh/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
# -> 2149         result = self._constructor(self._data.get(key))
#    2150         if result.columns.is_unique:
#    2151             result = result[key]
#
# ...

# %%
x = df[['Adj. Open']]
print (x)
# Out:
# <bound method DataFrame.sort_values of               Adj. Open    Adj. Open
# Date
# 2004-08-19    50.159839    50.159839
# 2004-08-20    50.661387    50.661387
# 2004-08-23    55.551482    55.551482
# 2004-08-24    55.792225    55.792225
# 2004-08-25    52.542193    52.542193
# 2004-08-26    52.637487    52.637487
# 2004-08-27    54.217364    54.217364
# 2004-08-30    52.802998    52.802998
# 2004-08-31    51.318415    51.318415
# 2004-09-01    51.509003    51.509003
# 2004-09-02    49.698414    49.698414
# 2004-09-03    50.631294    50.631294
# 2004-09-07    50.661387    50.661387
# 2004-09-08    50.525969    50.525969
# 2004-09-09    51.408694    51.408694
# 2004-09-10    50.892099    50.892099
# 2004-09-13    53.480088    53.480088
# 2004-09-14    53.886342    53.886342
# 2004-09-15    55.451172    55.451172
# 2004-09-16    56.343928    56.343928
# 2004-09-17    57.387149    57.387149
# 2004-09-20    58.656066    58.656066
# 2004-09-21    60.286097    60.286097
# ...

# %%
df.head()
# Out:
#             Adj. Open  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19  50.159839  50.159839  52.191109  48.128568   50.322842
# 2004-08-20  50.661387  50.661387  54.708881  50.405597   54.322689
# 2004-08-23  55.551482  55.551482  56.915693  54.693835   54.869377
# 2004-08-24  55.792225  55.792225  55.972783  51.945350   52.597363
# 2004-08-25  52.542193  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume    HL_PCT  PCT_Change
# Date
# 2004-08-19   44659000.0  3.712563    3.712563
# 2004-08-20   22834300.0  0.710922    0.710922
# 2004-08-23   18256100.0  3.729433    3.729433
# 2004-08-24   15247300.0  6.417469    6.417469
# 2004-08-25    9188600.0  1.886792    1.886792
