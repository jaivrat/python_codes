# %%
import pandas as pd
import quandl

# %%
df = quandl.get('WIKI/GOOGL')

# %%
df.head()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0  50.159839  52.191109  48.128568   50.322842
# 2004-08-20          1.0  50.661387  54.708881  50.405597   54.322689
# 2004-08-23          1.0  55.551482  56.915693  54.693835   54.869377
# 2004-08-24          1.0  55.792225  55.972783  51.945350   52.597363
# 2004-08-25          1.0  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# 2004-08-24   15247300.0
# 2004-08-25    9188600.0

# %%
#SOme feartues
df = df[['Adj. Open' , 'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume']]

# %%
df.head()
# Out:
#             Adj. Open  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19  50.159839  50.159839  52.191109  48.128568   50.322842
# 2004-08-20  50.661387  50.661387  54.708881  50.405597   54.322689
# 2004-08-23  55.551482  55.551482  56.915693  54.693835   54.869377
# 2004-08-24  55.792225  55.792225  55.972783  51.945350   52.597363
# 2004-08-25  52.542193  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# 2004-08-24   15247300.0
# 2004-08-25    9188600.0

# %%
#define new feature
df['HL_PCT'] = (df['Adj. High'] - df['Adj. Close'])/df['Adj. Close'] * 100
df['PCT_Change'] = (df['Adj. Close'] - df['Adj. Open'])/df['Adj. Open'] * 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-67dbae176344> in <module>()
#       1 #define new feature
#       2 df['HL_PCT'] = (df['Adj. High'] - df['Adj. Close'])/df['Adj. Close'] * 100
# ----> 3 df['PCT_Change'] = (df['Adj. Close'] - df['Adj. Open'])/df['Adj. Open'] * 100
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1260             return self._combine_frame(other, na_op, fill_value, level)
#    1261         elif isinstance(other, ABCSeries):
# -> 1262             return self._combine_series(other, na_op, fill_value, axis, level)
#    1263         else:
#    1264             if fill_value is not None:
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/frame.py in _combine_series(self, other, func, fill_value, axis, level, try_cast)
#    3942         return self._combine_series_infer(other, func, level=level,
#    3943                                           fill_value=fill_value,
# -> 3944                                           try_cast=try_cast)
#    3945
#    3946     def _combine_series_infer(self, other, func, level=None,
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/frame.py in _combine_series_infer(self, other, func, level, fill_value, try_cast)
#    3956         return self._combine_match_columns(other, func, level=level,
#    3957                                            fill_value=fill_value,
# -> 3958                                            try_cast=try_cast)
#    3959
#    3960     def _combine_match_index(self, other, func, level=None,
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/frame.py in _combine_match_columns(self, other, func, level, fill_value, try_cast)
#    3972                                fill_value=None, try_cast=True):
#    3973         left, right = self.align(other, join='outer', axis=1, level=level,
# -> 3974                                  copy=False)
#    3975         if fill_value is not None:
#    3976             raise NotImplementedError("fill_value %r not supported" %
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/frame.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    2917                                             method=method, limit=limit,
#    2918                                             fill_axis=fill_axis,
# -> 2919                                             broadcast_axis=broadcast_axis)
#    2920
#    2921     @Appender(_shared_docs['reindex'] % _shared_doc_kwargs)
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/generic.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    5728                                       copy=copy, fill_value=fill_value,
#    5729                                       method=method, limit=limit,
# -> 5730                                       fill_axis=fill_axis)
#    5731         else:  # pragma: no cover
#    5732             raise TypeError('unsupported type: %s' % type(other))
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/generic.py in _align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    5822                     join_index, lidx, ridx = self.columns.join(
#    5823                         other.index, how=join, level=level,
# -> 5824                         return_indexers=True)
#    5825
#    5826                 if lidx is not None:
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/indexes/base.py in join(self, other, how, level, return_indexers, sort)
#    3129             how = {'right': 'left', 'left': 'right'}.get(how, how)
#    3130             result = other.join(self, how=how, level=level,
# -> 3131                                 return_indexers=return_indexers)
#    3132             if return_indexers:
#    3133                 x, y, z = result
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py in join(self, other, how, level, return_indexers, sort)
#    1075         this, other = self._maybe_utc_convert(other)
#    1076         return Index.join(this, other, how=how, level=level,
# -> 1077                           return_indexers=return_indexers, sort=sort)
#    1078
#    1079     def _maybe_utc_convert(self, other):
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/indexes/base.py in join(self, other, how, level, return_indexers, sort)
#    3138             this = self.astype('O')
#    3139             other = other.astype('O')
# -> 3140             return this.join(other, how=how, return_indexers=return_indexers)
#    3141
#    3142         _validate_join_method(how)
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/indexes/base.py in join(self, other, how, level, return_indexers, sort)
#    3148             if self.is_monotonic and other.is_monotonic:
#    3149                 return self._join_monotonic(other, how=how,
# -> 3150                                             return_indexers=return_indexers)
#    3151             else:
#    3152                 return self._join_non_unique(other, how=how,
#
# ~/anaconda/envs/my_app3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _join_monotonic(self, other, how, return_indexers)
#    3413                 join_index, lidx, ridx = self._inner_indexer(sv, ov)
#    3414             elif how == 'outer':
# -> 3415                 join_index, lidx, ridx = self._outer_indexer(sv, ov)
#    3416             join_index = self._wrap_joined_index(join_index, other)
#    3417
#
# pandas/_libs/join_helper.pxi in pandas._libs.join.outer_join_indexer_object()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib._Timestamp.__richcmp__()
#
# TypeError: Cannot compare type 'Timestamp' with type 'str'

# %%
x = df['Adj. Open']
x.sort_values
# Out:
# <bound method DataFrame.sort_values of               Adj. Open    Adj. Open
# Date
# 2004-08-19    50.159839    50.159839
# 2004-08-20    50.661387    50.661387
# 2004-08-23    55.551482    55.551482
# 2004-08-24    55.792225    55.792225
# 2004-08-25    52.542193    52.542193
# 2004-08-26    52.637487    52.637487
# 2004-08-27    54.217364    54.217364
# 2004-08-30    52.802998    52.802998
# 2004-08-31    51.318415    51.318415
# 2004-09-01    51.509003    51.509003
# 2004-09-02    49.698414    49.698414
# 2004-09-03    50.631294    50.631294
# 2004-09-07    50.661387    50.661387
# 2004-09-08    50.525969    50.525969
# 2004-09-09    51.408694    51.408694
# 2004-09-10    50.892099    50.892099
# 2004-09-13    53.480088    53.480088
# 2004-09-14    53.886342    53.886342
# 2004-09-15    55.451172    55.451172
# 2004-09-16    56.343928    56.343928
# 2004-09-17    57.387149    57.387149
# 2004-09-20    58.656066    58.656066
# 2004-09-21    60.286097    60.286097
# 2004-09-22    58.906840    58.906840
# 2004-09-23    59.603992    59.603992
# 2004-09-24    60.672290    60.672290
# 2004-09-27    59.965107    59.965107
# 2004-09-28    60.762568    60.762568
# 2004-09-29    63.460898    63.460898
# 2004-09-30    65.150614    65.150614
# ...                 ...          ...
# 2017-11-20  1036.000000  1036.000000
# 2017-11-21  1040.040000  1040.040000
# 2017-11-22  1051.160000  1051.160000
# 2017-11-24  1054.390000  1054.390000
# 2017-11-27  1058.570000  1058.570000
# 2017-11-28  1073.990000  1073.990000
# 2017-11-29  1056.180000  1056.180000
# 2017-11-30  1039.940000  1039.940000
# 2017-12-01  1030.410000  1030.410000
# 2017-12-04  1027.800000  1027.800000
# 2017-12-05  1010.990000  1010.990000
# 2017-12-06  1016.520000  1016.520000
# 2017-12-07  1036.070000  1036.070000
# 2017-12-08  1051.810000  1051.810000
# 2017-12-11  1051.110000  1051.110000
# 2017-12-12  1050.000000  1050.000000
# 2017-12-13  1052.080000  1052.080000
# 2017-12-14  1055.490000  1055.490000
# 2017-12-15  1063.780000  1063.780000
# 2017-12-18  1076.450000  1076.450000
# 2017-12-19  1083.020000  1083.020000
# 2017-12-20  1080.920000  1080.920000
# 2017-12-21  1075.390000  1075.390000
# 2017-12-22  1070.000000  1070.000000
# 2017-12-26  1068.640000  1068.640000
# 2017-12-27  1066.600000  1066.600000
# 2017-12-28  1062.250000  1062.250000
# 2017-12-29  1055.490000  1055.490000
# 2018-01-02  1053.020000  1053.020000
# 2018-01-03  1073.930000  1073.930000
#
# [3367 rows x 2 columns]>

# %%
df.head()
# Out:
#             Adj. Open  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19  50.159839  50.159839  52.191109  48.128568   50.322842
# 2004-08-20  50.661387  50.661387  54.708881  50.405597   54.322689
# 2004-08-23  55.551482  55.551482  56.915693  54.693835   54.869377
# 2004-08-24  55.792225  55.792225  55.972783  51.945350   52.597363
# 2004-08-25  52.542193  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume    HL_PCT  PCT_Change
# Date
# 2004-08-19   44659000.0  3.712563    3.712563
# 2004-08-20   22834300.0  0.710922    0.710922
# 2004-08-23   18256100.0  3.729433    3.729433
# 2004-08-24   15247300.0  6.417469    6.417469
# 2004-08-25    9188600.0  1.886792    1.886792
