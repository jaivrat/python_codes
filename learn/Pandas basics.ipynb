# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

style.use('ggplot')

# %%
web_stats = {'Day': [1,2,3,4,5,6], 
             'Visitors': [43,5,67,22,11,10], 
             'Bounce_Rate': [65, 44, 3, 23, 4, 40]
            }

web_stats
# Out:
# {'Bounce_Rate': [65, 44, 3, 23, 4, 40],
#  'Day': [1, 2, 3, 4, 5, 6],
#  'Visitors': [43, 5, 67, 22, 11, 10]}

# %%
df = pd.DataFrame(web_stats)

# %%
print df
# Out:
#    Bounce_Rate  Day  Visitors
# 0           65    1        43
# 1           44    2         5
# 2            3    3        67
# 3           23    4        22
# 4            4    5        11
# 5           40    6        10

# %%
df.head()
# Out:
#    Bounce_Rate  Day  Visitors
# 0           65    1        43
# 1           44    2         5
# 2            3    3        67
# 3           23    4        22
# 4            4    5        11

# %%
df.tail()
# Out:
#    Bounce_Rate  Day  Visitors
# 1           44    2         5
# 2            3    3        67
# 3           23    4        22
# 4            4    5        11
# 5           40    6        10

# %%
df.tail(2)
# Out:
#    Bounce_Rate  Day  Visitors
# 4            4    5        11
# 5           40    6        10

# %%
x = df.set_index('Day')

# %%
x
# Out:
#      Bounce_Rate  Visitors
# Day
# 1             65        43
# 2             44         5
# 3              3        67
# 4             23        22
# 5              4        11
# 6             40        10

# %%
x['Bounce_Rate'].tolist()
# Out:
# [65, 44, 3, 23, 4, 40]

# %%
type(x['Bounce_Rate'])
# Out:
# pandas.core.series.Series

# %%
import numpy as np
np.array(x['Bounce_Rate'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d02320f13671> in <module>()
#       1 import numpy as np
# ----> 2 np.array(x['Bounce_Rate'])
#
# NameError: name 'x' is not defined

# %%
#Pandas io

# %%
import quandl as qd
import pandas as pd

# %%
api_key='BRZgSj1cfrBUZDD2Ed49'

# %%
df = qd.get('FMAC/HPI_AK', authtoken=api_key)

# %%
df.head()
# Out:
#                 Value
# Date
# 1975-01-31  34.433211
# 1975-02-28  34.941605
# 1975-03-31  35.461275
# 1975-04-30  36.002408
# 1975-05-31  36.592509

# %%
s = pd.Series([80, 20, 30, 40])
s
# Out:
# 0    80
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import html5lib
states_wiki ='https://simple.wikipedia.org/wiki/List_of_U.S._states'
fifty_states = pd.read_html(states_wiki)

# %%
collect = {}

for abbv in fifty_states[0][0][1:]:
    param = 'FMAC/HPI_' + abbv
    tmpdf = qd.get('FMAC/HPI_AK', authtoken=api_key)
    collect[param] = tmpdf

# %%
import pandas as pd

df1 = pd.DataFrame({'a': [ 1, 2, 3, 4, 5],
                   'b': [ 'A', 'L', 'P', 'H', 'A']})

df1.set_index('a', inplace=True)
df1
# Out:
#    b
# a
# 1  A
# 2  L
# 3  P
# 4  H
# 5  A

# %%
df2 = pd.DataFrame({'a': [ 1, 2, 3, 4, 8],
                   'b': [ 'B', 'O', 'M', 'X', 'Y']})

df2.set_index('a', inplace=True)
df2
# Out:
#    b
# a
# 1  B
# 2  O
# 3  M
# 4  X
# 8  Y

# %%
collect.get(1)

# %%
tmpdf = qd.get('FMAC/HPI_AL', authtoken=api_key)
tmpdf
tmpdf.columns = ['AL']
tmpdf
# Out:
#                     AL
# Date
# 1975-01-31   35.467079
# 1975-02-28   35.693905
# 1975-03-31   35.956499
# 1975-04-30   36.273871
# 1975-05-31   36.570739
# 1975-06-30   36.726116
# 1975-07-31   36.671478
# 1975-08-31   36.449231
# 1975-09-30   36.194657
# 1975-10-31   36.069713
# 1975-11-30   36.158300
# 1975-12-31   36.477560
# 1976-01-31   37.000527
# 1976-02-29   37.604315
# 1976-03-31   38.127187
# 1976-04-30   38.469711
# 1976-05-31   38.644861
# 1976-06-30   38.724613
# 1976-07-31   38.793010
# 1976-08-31   38.855545
# 1976-09-30   38.895449
# 1976-10-31   38.956761
# 1976-11-30   39.099480
# 1976-12-31   39.260450
# 1977-01-31   39.345249
# 1977-02-28   39.381711
# 1977-03-31   39.437980
# 1977-04-30   39.620845
# 1977-05-31   39.948349
# 1977-06-30   40.371199
# ...                ...
# 2014-10-31  123.372801
# 2014-11-30  122.832902
# 2014-12-31  122.770149
# 2015-01-31  123.129701
# 2015-02-28  123.655312
# 2015-03-31  124.412455
# 2015-04-30  125.382498
# ...

# %%
fifty_states[0][0][1:]
# Out:
# 1     AL
# 2     AK
# 3     AZ
# 4     AR
# 5     CA
# 6     CO
# 7     CT
# 8     DE
# 9     FL
# 10    GA
# 11    HI
# 12    ID
# 13    IL
# 14    IN
# 15    IA
# 16    KS
# 17    KY
# 18    LA
# 19    ME
# 20    MD
# 21    MA
# 22    MI
# 23    MN
# 24    MS
# 25    MO
# 26    MT
# 27    NE
# 28    NV
# 29    NH
# 30    NJ
# 31    NM
# 32    NY
# 33    NC
# 34    ND
# 35    OH
# 36    OK
# 37    OR
# 38    PA
# 39    RI
# 40    SC
# 41    SD
# 42    TN
# 43    TX
# 44    UT
# 45    VT
# 46    VA
# 47    WA
# 48    WV
# 49    WI
# 50    WY
# Name: 0, dtype: object

# %%
main_df = pd.DataFrame()

for abbv in fifty_states[0][0][1:]:
    param = 'FMAC/HPI_' + abbv
    #print("getting " + param)
    tmpdf = qd.get(param, authtoken=api_key)
    #tmpdf.set_index('Date', inplace=True)
    #print tmpdf.index
    tmpdf.columns = [abbv]
    #tmpdf = tmpdf.pct_change()
    tmpdf[abbv] = (tmpdf[abbv] - tmpdf[abbv][0])/tmpdf[abbv][0] * 100
    if main_df.empty:
        main_df = tmpdf
    else:
        main_df = main_df.join(tmpdf)

print(main_df.head())
# Out:
#                   AL        AK        AZ        AR        CA        CO  \
# Date
# 1975-01-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1975-02-28  0.639537  1.476464  1.777284  0.977486  0.370816  1.148304
# 1975-03-31  1.379926  2.985676  3.441061  1.834722  1.606742  2.281095
# 1975-04-30  2.274762  4.557219  4.711573  2.532148  3.611061  3.334637
# 1975-05-31  3.111785  6.270974  5.336602  3.181654  5.281684  4.211235
#
#                   CT        DE         FL        GA    ...           SD  \
# Date                                                   ...
# 1975-01-31  0.000000  0.000000   0.000000  0.000000    ...     0.000000
# 1975-02-28  2.179282  0.077291   3.798945 -0.974251    ...    -1.130463
# 1975-03-31  3.820370  0.257269   9.479232 -1.409251    ...    -2.279081
# 1975-04-30  4.729187  0.696204  16.476429 -1.224007    ...    -3.419103
# 1975-05-31  4.981166  1.495737  17.250125 -0.827153    ...    -4.454912
#
# ...

# %%
main_df = qd.get('FMAC/HPI_AL', authtoken=api_key)
main_df.columns = ['AL']
main_df
# Out:
#                     AL
# Date
# 1975-01-31   35.467079
# 1975-02-28   35.693905
# 1975-03-31   35.956499
# 1975-04-30   36.273871
# 1975-05-31   36.570739
# 1975-06-30   36.726116
# 1975-07-31   36.671478
# 1975-08-31   36.449231
# 1975-09-30   36.194657
# 1975-10-31   36.069713
# 1975-11-30   36.158300
# 1975-12-31   36.477560
# 1976-01-31   37.000527
# 1976-02-29   37.604315
# 1976-03-31   38.127187
# 1976-04-30   38.469711
# 1976-05-31   38.644861
# 1976-06-30   38.724613
# 1976-07-31   38.793010
# 1976-08-31   38.855545
# 1976-09-30   38.895449
# 1976-10-31   38.956761
# 1976-11-30   39.099480
# 1976-12-31   39.260450
# 1977-01-31   39.345249
# 1977-02-28   39.381711
# 1977-03-31   39.437980
# 1977-04-30   39.620845
# 1977-05-31   39.948349
# 1977-06-30   40.371199
# ...                ...
# 2014-10-31  123.372801
# 2014-11-30  122.832902
# 2014-12-31  122.770149
# 2015-01-31  123.129701
# 2015-02-28  123.655312
# 2015-03-31  124.412455
# 2015-04-30  125.382498
# ...

# %%
tmpdf = qd.get('FMAC/HPI_AK', authtoken=api_key)
tmpdf.columns = ['AK']
tmpdf
print tmpdf.index
print main_df.index
main_df.join(tmpdf)
# Out:
# DatetimeIndex(['1975-01-31', '1975-02-28', '1975-03-31', '1975-04-30',
#                '1975-05-31', '1975-06-30', '1975-07-31', '1975-08-31',
#                '1975-09-30', '1975-10-31',
#                ...
#                '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30',
#                '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31',
#                '2017-02-28', '2017-03-31'],
#               dtype='datetime64[ns]', name=u'Date', length=507, freq=None)
# DatetimeIndex(['1975-01-31', '1975-02-28', '1975-03-31', '1975-04-30',
#                '1975-05-31', '1975-06-30', '1975-07-31', '1975-08-31',
#                '1975-09-30', '1975-10-31',
#                ...
#                '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30',
#                '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31',
#                '2017-02-28', '2017-03-31'],
#               dtype='datetime64[ns]', name=u'Date', length=507, freq=None)
#                     AL          AK
# ...

# %%
import pickle
pickel_out = open('states_pickle', 'wb')
pickle.dump(main_df, pickel_out)
pickel_out.close()

# %%
main_df_pickled = open('states_pickle', 'rb')
HPI_data = pickle.load(main_df_pickled)

# %%
HPI_data
# Out:
#                     AL          AK          AZ          AR          CA  \
# Date
# 1975-01-31   35.467079   34.433211   28.935033   36.794925   15.674160
# 1975-02-28   35.693905   34.941605   29.449291   37.154591   15.732283
# 1975-03-31   35.956499   35.461275   29.930705   37.470010   15.926004
# 1975-04-30   36.273871   36.002408   30.298328   37.726627   16.240164
# 1975-05-31   36.570739   36.592509   30.479180   37.965613   16.502020
# 1975-06-30   36.726116   37.223771   30.414642   38.207976   16.618509
# 1975-07-31   36.671478   37.855241   30.093756   38.413771   16.741526
# 1975-08-31   36.449231   38.431024   29.601107   38.533930   16.962664
# 1975-09-30   36.194657   38.933066   29.091587   38.535637   17.201702
# 1975-10-31   36.069713   39.390363   28.809024   38.482970   17.417696
# 1975-11-30   36.158300   39.799107   28.925032   38.507549   17.564070
# 1975-12-31   36.477560   40.139340   29.298288   38.644013   17.687809
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')

main_df.plot()
plt.legend().remove()
plt.show()

# %%
def HPI_benchmark():
    df = qd.get('FMAC/HPI_USA', authtoken=api_key)
    df['United States'] = (df['United States'] - df['United States'][0])/df['United States'][0] * 100
    return df


main_df['AK'].plot()
plt.show()
