# %%
## Web scrape - scrape stock data

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Create two empty lists for the company names and the ticker

# %%
company_name = []
company_ticker = []

# %%
# https://www.advfn.com/

# %%
URL = "https://www.advfn.com/stock-market/EURONEXT/UKX/historical"
page = requests.get(URL)

# %%
# <Response [200]> means all good
page
# Out:
# <Response [200]>

# %%
#
page.text[1:100]
# Out:
# '!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">\n<html lan'

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
#
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">
# window.USER_COUNTRY = "SG";
# window.USER_STATE = "";
# window.USER_FROM_EU = "";
# </script>
# <!-- APS_HEADER_START -->
# <script type="text/javascript">
# function AdvfnJsQueueLoader(e){this.check=e,this.queue=[],this.id=!1,this.ready=!1;var t=this;this.id=setInterval(function(){t.tick()},50)}AdvfnJsQueueLoader.prototype.processQueue=function(){var e;if(0<this.queue.length)for(e=0;e<this.queue.length;e++)this.queue[e]()},AdvfnJsQueueLoader.prototype.tick=function(){this.check()&&(clearInterval(this.id),this.ready=!0,this.processQueue())},AdvfnJsQueueLoader.prototype.add=function(e){this.ready?e():this.queue.push(e)};
# var jqueryReady=new AdvfnJsQueueLoader(function(){return'function'==typeof $});
# </script>
# ...

# %%
odd_rows = soup.find_all('tr', attrs = {'class': ['odd', 'even']})

# %%
odd_rows
# Out:
# [<tr class="odd">
#  <td align="center"><b>HSBC Securities Services Ireland Limited</b></td>
#  <td align="center"><b>UKX</b></td>
#  <td align="center"><b>Euronext</b></td>
#  <td align="center"><span class="" id="quoteElementPiece1">Exchange Traded Fund</span></td>
#  <td align="center"><span class="" id="quoteElementPiece2">IE00B42TW061</span></td>
#  <td align="center">HSBC FTSE 100 UCITS ETF</td>
#  </tr>,
#  <tr class="odd">
#  <td align="center" class="change_arrow_fa"><span class="PriceTextUp" id="quoteElementPiece3"><span class="fa fa-arrow-up PriceTextUp fa-fw"></span></span></td>
#  <td align="center" class="change"><span class="PriceTextUp" id="quoteElementPiece4">0.27</span></td>
#  <td align="center" class="chgpct"><span class="PriceTextUp" id="quoteElementPiece5">0.44%</span></td>
#  <td align="center" class="current_price"><span class="PriceTextUp" id="quoteElementPiece6">61.92</span></td>
# ...

# %%
for i in odd_rows:
    row = i.find_all('td')
    print(type(row))
# Out:
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# ...
