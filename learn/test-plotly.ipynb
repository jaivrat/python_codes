# %%
import plotly

# %%
plotly.__version__
# Out:
# '4.7.1'

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
iplot([{"x" : [ 1, 2, 3, 4, 5], "y": [1.2, 1.2, 1.5, 0.3, 2.0]}])
# Out:
# <div>
#
#
#             <div id="2bdb54e7-9700-420c-b1e4-7522baeccbc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2bdb54e7-9700-420c-b1e4-7522baeccbc5")) {
#                     Plotly.newPlot(
#                         '2bdb54e7-9700-420c-b1e4-7522baeccbc5',
#                         [{"type": "scatter", "x": [1, 2, 3, 4, 5], "y": [1.2, 1.2, 1.5, 0.3, 2.0]}],
# ...

# %%
import plotly.graph_objs as go
import numpy as np


x = np.random.randn(2000)
y = np.random.randn(2000)

iplot([go.Histogram2dcontour(x=x, y=y, contours=dict(coloring='heatmap'))])
# Out:
# /Users/jvsingh/anaconda3/envs/plotly_env/lib/python3.6/site-packages/plotly/graph_objs/_deprecations.py:721: DeprecationWarning:
#
# plotly.graph_objs.Histogram2dcontour is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.Histogram2dContour
# <div>
#
#
#             <div id="591ca981-cf85-48d0-9fe8-86a7c0712494" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("591ca981-cf85-48d0-9fe8-86a7c0712494")) {
#                     Plotly.newPlot(
#                         '591ca981-cf85-48d0-9fe8-86a7c0712494',
# ...

# %%
iplot([go.Histogram2dcontour(x=x, y=y, contours=dict(coloring='heatmap')),
       go.Scatter(x = x, y=y, mode='markers', marker=dict(color='white', size=3, opacity=0.3))])
# Out:
# <div>
#
#
#             <div id="c0f95989-4c07-44ea-b129-b0c9101debe0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c0f95989-4c07-44ea-b129-b0c9101debe0")) {
#                     Plotly.newPlot(
#                         'c0f95989-4c07-44ea-b129-b0c9101debe0',
# ...

# %%
iplot([go.Histogram2dcontour(x=x, y=y, contours=dict(coloring='heatmap')),
       go.Scatter(x = x, y=y, mode='markers', marker=dict(color='white', size=3, opacity=0.3))],
     show_link = False)
# Out:
# <div>
#
#
#             <div id="f1ae5636-6434-4197-8ed1-846434377717" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f1ae5636-6434-4197-8ed1-846434377717")) {
#                     Plotly.newPlot(
#                         'f1ae5636-6434-4197-8ed1-846434377717',
# ...

# %% [markdown]
# ### LEARN PLOTLY | GETTING STARTED WITH SCATTERPLOT AND PIE CHART

# %%
#!pip install chart_studio
import chart_studio.plotly as py
import plotly.graph_objs as go
import numpy as np

# %%
N = 100
example_x = np.random.rand(N)
example_y = np.random.rand(N)

# %%
trace = go.Scatter(
    x = example_x,
    y = example_y,
    mode = 'markers')

# %%
data = [trace]
iplot(data)
# Out:
# <div>
#
#
#             <div id="54c57bfd-9217-4c9b-9a6a-1f96e838637d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54c57bfd-9217-4c9b-9a6a-1f96e838637d")) {
#                     Plotly.newPlot(
#                         '54c57bfd-9217-4c9b-9a6a-1f96e838637d',
# ...

# %% [markdown]
# ##### PIE CHART CREATION

# %%
#Expenses

#breakdown each category 
groups = ['Rent','Food','Bills','Miscellaneous']
#create amount
amount = [1000,518,331,277]
#style
colors = ['#d32c58', '#f9b1ee', '#b7f9b1', '#b1f5f9']

trace = go.Pie(labels=groups, values=amount,
               hoverinfo='label+percent', textinfo='value', 
               textfont=dict(size=25),
               marker=dict(colors=colors, 
                           line=dict(color='#000000', width=3)))

#plot - 
iplot([trace])
# Out:
# <div>
#
#
#             <div id="93d5ba3b-2f3f-4a6f-b37d-c8165cb310f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("93d5ba3b-2f3f-4a6f-b37d-c8165cb310f9")) {
#                     Plotly.newPlot(
#                         '93d5ba3b-2f3f-4a6f-b37d-c8165cb310f9',
#                         [{"hoverinfo": "label+percent", "labels": ["Rent", "Food", "Bills", "Miscellaneous"], "marker": {"colors": ["#d32c58", "#f9b1ee", "#b7f9b1", "#b1f5f9"], "line": {"color": "#000000", "width": 3}}, "textfont": {"size": 25}, "textinfo": "value", "type": "pie", "values": [1000, 518, 331, 277]}],
# ...

# %% [markdown]
# ## LEARN PLOTLY - WORKING WITH CUSTOM DATA

# %%
import pandas as pd

pubg = pd.read_csv("/Users/jvsingh/Downloads/P48-Custom-Data-PUBG.csv")
df_pubg = pubg.apply(pd.to_numeric, errors='ignore')
df_new_pubg = df_pubg.head(10)
df_new_pubg
# Out:
#      player_name  tracker_id  solo_KillDeathRatio  solo_WinRatio  \
# 0      BreakNeck        4405                 3.14          17.65
# 1      Blackwalk        8199                 4.41          18.18
# 2  mercedes_benz        4454                 3.60           0.00
# 3           DORA        7729                14.00          50.00
# 4        n2tstar           0                10.50          33.33
# 5     coldoxygen       33313                 5.73          31.25
# 6          Giken       15585                 2.45           8.45
# 7       KoreaNo1        9454                 2.71          26.32
# 8          undor       24029                 3.68          13.64
# 9        Fordune       11289                 4.17          25.00
#
#    solo_TimeSurvived  solo_RoundsPlayed  solo_Wins  solo_WinTop10Ratio  \
# 0           18469.14                 17          3                0.83
# 1           33014.86                 33          6                0.36
# ...

# %%
trace = go.Scatter(x = df_new_pubg['solo_RoundsPlayed'], 
                  y = df_new_pubg['solo_Wins'],
                  name='Rounds Won')

layout = go.Layout(title = "PUBG Wind vs Rounds Played",
                  plot_bgcolor = 'rgb(230, 230, 230)',
                  showlegend = True)

fig = go.Figure(data=[trace], layout=layout)

iplot(fig)
# Out:
# <div>
#
#
#             <div id="3768f864-6127-4592-9e2c-db58b229f695" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3768f864-6127-4592-9e2c-db58b229f695")) {
#                     Plotly.newPlot(
#                         '3768f864-6127-4592-9e2c-db58b229f695',
#                         [{"name": "Rounds Won", "type": "scatter", "x": [17, 33, 5, 8, 6, 16, 142, 19, 44, 8], "y": [3, 6, 0, 4, 2, 5, 12, 5, 6, 2]}],
# ...

# %%
df_new_pubg = df_pubg.head(50)

trace1 = go.Bar(x = df_new_pubg['player_name'], 
                  y = df_new_pubg['solo_RoundsPlayed'],
                  name='Rounds Played')

trace2 = go.Bar(x = df_new_pubg['player_name'], 
                  y = df_new_pubg['solo_Wins'],
                  name=' Wins')

# %%
#call date and plots for visualization

layout = go.Layout(barmode = 'group')

fig = go.Figure(data = [trace1, trace2], layout=layout)

iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="1778b335-4db5-44c1-818b-a952a8fab95c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1778b335-4db5-44c1-818b-a952a8fab95c")) {
#                     Plotly.newPlot(
#                         '1778b335-4db5-44c1-818b-a952a8fab95c',
# ...
